# %% [markdown]
# <a href="https://colab.research.google.com/github/nakyeong-kim/CodingTest/blob/main/5_2_%EC%9D%B4%EC%A7%84%ED%8A%B8%EB%A6%AC%EC%88%9C%ED%9A%8C(%EA%B9%8A%EC%9D%B4%EC%9A%B0%EC%84%A0%ED%83%90%EC%83%89).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### DFS(깊이우선탐색)의 종류에 전/중/후위 순회가 있음
# - 전위 순회 : 부모 → 왼쪽자식 → 오른쪽자식
# - 중위 순회 : 왼쪽자식 → 부모 → 오른쪽자식
# - 후위 순회 : 왼쪽자식 → 오른쪽자식 → 부모

# %%
# 전위 순회

def DFS(n):
  if n > 7:
    return
  print(n, end=' ')
  DFS(n*2)    # 왼쪽자식 노드 호출
  DFS(n*2+1)  # 오른쪽자식 노드 호출

if __name__=="__main__":
  DFS(1)
# Out:
# 1 2 4 5 3 6 7

# %%
# 중위 순회

def DFS(n):
  if n > 7:
    return
  DFS(n*2)    # 왼쪽자식 노드 호출
  print(n, end=' ')
  DFS(n*2+1)  # 오른쪽자식 노드 호출

if __name__=="__main__":
  DFS(1)
# Out:
# 4 2 5 1 6 3 7

# %%
# 후위 순회

def DFS(n):
  if n > 7:
    return
  DFS(n*2)    # 왼쪽자식 노드 호출
  DFS(n*2+1)  # 오른쪽자식 노드 호출
  print(n, end=' ')

if __name__=="__main__":
  DFS(1)
# Out:
# 4 5 2 6 7 3 1
